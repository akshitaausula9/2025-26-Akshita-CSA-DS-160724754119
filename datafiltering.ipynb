# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaausula9/2025-26-Akshita-CSA-DS-160724754119/blob/main/datafiltering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Filtering
import pandas as pd
data={
    "ID":[101,102,103,104,105],
    "Name":["Alice","Bob","Charlie","David","Eva"],
    "Age":[22,25,23,24,26],
    "Marks":[85,78,92,88,90]
}
df=pd.DataFrame(data)
print("Original Data:")
print(df)
print("\nFiltering data where Names are Alice or Charlie\n")
print(df[(df["Name"] == 'Alice') | (df["Name"] == 'Charlie')])
print("\nFiltering data where Marks is greater than 85\n")
print(df[df["Marks"]>85])
print("\nFiltering data where Age is less than 25\n")
print(df[df["Age"]<25])
# Out:
# Original Data:
#     ID     Name  Age  Marks
# 0  101    Alice   22     85
# 1  102      Bob   25     78
# 2  103  Charlie   23     92
# 3  104    David   24     88
# 4  105      Eva   26     90
#
# Filtering data where Names are Alice or Charlie
#
#     ID     Name  Age  Marks
# 0  101    Alice   22     85
# 2  103  Charlie   23     92
#
# Filtering data where Marks is greater than 85
#
#     ID     Name  Age  Marks
# 2  103  Charlie   23     92
# 3  104    David   24     88
# 4  105      Eva   26     90
#
# Filtering data where Age is less than 25
#
#     ID     Name  Age  Marks
# 0  101    Alice   22     85
# 2  103  Charlie   23     92
# 3  104    David   24     88
