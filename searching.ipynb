# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaausula9/2025-26-Akshita-CSA-DS-160724754119/blob/main/searching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear search
def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1


arr = [10, 20, 30, 40, 50]
key = 30

result = linear_search(arr, key)

if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")
# Out:
# Element found at index: 2

# %%
#Binary Search

n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

arr.sort()
print("\n sorted list : arr")

key = int(input("enter element to search:"))

low = 0
high = n-1

found = False
while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        print(f"element {key} found at position {mid+1}")
        found = True
        break

    elif key < arr[mid]:
        high = mid - 1
    else:
      low=mid+1
    if not found:
      print ("element not found")
# Out:
# enter number of elements:4
# enter element 1:5
# enter element 2:6
# enter element 3:7
# enter element 4:8
#
#  sorted list : arr
# enter element to search:7
# element not found
# element 7 found at position 3
