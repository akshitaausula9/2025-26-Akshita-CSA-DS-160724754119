# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaausula9/2025-26-Akshita-CSA-DS-160724754119/blob/main/datadistribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
normal_data=np.random.normal(loc=50,scale=6,size=100)
right_skewed=np.random.exponential(scale=3,size=100)
left_skewed=-np.random.exponential(scale=5,size=100)
plt.hist(normal_data,bins=40)
plt.title("Normal Distribution")
plt.show()
plt.hist(right_skewed,bins=40)
plt.title("Right Skewed Distribution")
plt.show()
plt.hist(left_skewed,bins=40)
plt.title("Left Skewed Distribution")
plt.show()
print("Normal Data Mean:",np.mean(normal_data))
print("Normal Data Median:",np.median(normal_data))
print("Right Skewed Mean:",np.mean(right_skewed))
print("Right Skewed Median:",np.median(right_skewed))
print("Left Skewed Mean:",np.mean(left_skewed))
print("Left Skewed Median:",np.median(left_skewed))
# Out:
# Normal Data Mean: 50.97329621089155
# Normal Data Median: 51.20653668554993
# Right Skewed Mean: 2.9266554659553607
# Right Skewed Median: 2.1190159643170032
# Left Skewed Mean: -4.80540965494041
# Left Skewed Median: -3.9983620203473667
