# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaausula9/2025-26-Akshita-CSA-DS-160724754119/blob/main/setoperation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SET OPERATIONS
s1 = {12,22,33,44}
s2 = {31,44,55,66}
print("Union using method:", s1.union(s2))
print("Intersection using method:", s1.intersection(s2))
print("Difference using method:", s1.difference(s2))
print("Symmetric difference using method:", s1.symmetric_difference(s2))
# Out:
# Union using method: {33, 66, 12, 44, 22, 55, 31}
# Intersection using method: {44}
# Difference using method: {33, 12, 22}
# Symmetric difference using method: {33, 66, 12, 22, 55, 31}
