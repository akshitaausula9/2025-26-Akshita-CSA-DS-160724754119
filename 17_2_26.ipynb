# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaausula9/2025-26-Akshita-CSA-DS-160724754119/blob/main/17_2_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = [10, 12, 15, 18, 20, 22, 25, 30, 35, 40]
df = pd.DataFrame(data, columns=["values"])
print("Dataset:")
print(df)
print("\nSummary statistics:")
print(df.describe())
print("\nVariance:", np.var(data))
print("Standard deviation:", np.std(data))
plt.hist(data, bins=5, edgecolor='black')
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Data Distribution")
plt.show()
mean_value = np.mean(data)
median_value = np.median(data)
print("\nInference:")
print("Mean value:", mean_value)
print("Median value:", median_value)

if mean_value > median_value:
    print("Data is slightly right-skewed")
elif mean_value < median_value:
    print("Data is slightly left-skewed")
else:
    print("Data is symmetric")
# Out:
# Dataset:
#    values
# 0      10
# 1      12
# 2      15
# 3      18
# 4      20
# 5      22
# 6      25
# 7      30
# 8      35
# 9      40
#
# Summary statistics:
#           values
# count  10.000000
# mean   22.700000
# std     9.855061
# min    10.000000
# 25%    15.750000
# 50%    21.000000
# 75%    28.750000
# max    40.000000
#
# Variance: 87.41
# Standard deviation: 9.34933152690608
# Inference:
# Mean value: 22.7
# Median value: 21.0
# Data is slightly right-skewed

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load Iris dataset (working public CSV link)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

print("Dataset (first 10 rows):")
print(df.head(10))

# Select the sepal length column
data = df["sepal_length"]

print("\nSummary Statistics:")
print(data.describe())

print("\nVariance:", np.var(data))
print("Standard Deviation:", np.std(data))

# Plot histogram
plt.figure(figsize=(8,5))
plt.hist(data, bins=10, color='skyblue', edgecolor='black')

# Mean line
plt.axvline(np.mean(data), color='red', linestyle='dashed',
            linewidth=2, label=f"Mean: {np.mean(data):.2f}")

# Median line
plt.axvline(np.median(data), color='green', linestyle='dashed',
            linewidth=2, label=f"Median: {np.median(data):.2f}")

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.title("Distribution of Sepal Length")
plt.legend()
plt.show()

# Skewness inference
mean_value = np.mean(data)
median_value = np.median(data)

print("\nInference:")
print("Mean value:", mean_value)
print("Median value:", median_value)

if mean_value > median_value:
    print("Data is slightly right-skewed")
elif mean_value < median_value:
    print("Data is slightly left-skewed")
else:
    print("Data is symmetric")
# Out:
# Dataset (first 10 rows):
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa
#
# Summary Statistics:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64
#
# Variance: 0.6811222222222222
# Standard Deviation: 0.8253012917851409
# Inference:
# Mean value: 5.843333333333334
# Median value: 5.8
# Data is slightly right-skewed
